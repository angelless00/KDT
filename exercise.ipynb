# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup

url=f'https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=1&sido=&gugun=&store='
html=urlopen(url)
soup=BeautifulSoup(html,'html.parser')

# %%
import pandas as pd

cafe_data=pd.read_csv(r'C:\KDT\과제\웹크롤링\0812\hollys_branches.csv')
cafe_data
# Out:
#           매장이름          지역                                                 주소  \
# 0       분당미금점2  경기 성남시 분당구     경기도 성남시 분당구 미금일로90번길 24 (구미동) 구미동 35-3, B1F~1F
# 1      인천굴포천역점      인천 부평구  인천광역시 부평구 충선로209번길 49 (삼산동, 삼산노블시티프라자) 삼산동 463...
# 2     대구팔달교DT점       대구 서구                                    대구광역시 서구 팔달로 34
# 3    인천공항교통센터점       인천 중구  인천광역시 중구 공항로 272 (운서동, 인천공항) 인천국제공항 제1여객터미널 지하...
# 4      한국선원센터점       부산 중구  부산광역시 중구 충장대로9번길 66 (중앙동4가, 한국선원센터) (중앙동4가 74-...
# ..         ...         ...                                                ...
# 490       합정역점      서울 마포구                   서울특별시 마포구 양화로 36 (합정동 374-1) 할리스
# 491     부산달맞이점     부산 해운대구         부산광역시 해운대구 달맞이길 199, 2~3층 (중동 1488-14) 할리스
# 492        신림점      서울 관악구                                서울특별시 관악구 신림로 353-1
# 493       태평로점       서울 중구         서울특별시 중구 세종대로 64, 해남빌딩 1층 (태평로2가 70-5) 할리스
# 494        신촌점     서울 서대문구                 서울특별시 서대문구 연세로 34 (창천동 31-12)  할리스
#
#               전화번호
# ...

# %%
for i in cafe_data.index:
    if '대구' in cafe_data.loc[i,'주소']:
        print(cafe_data.iloc[i])
# Out:
# 매장이름           대구팔달교DT점
# 지역                대구 서구
# 주소      대구광역시 서구 팔달로 34
# 전화번호       053-354-1212
# Name: 2, dtype: object
# 매장이름                           대구장기점
# 지역                            대구 달서구
# 주소      대구광역시 달서구 장기로 268 (장기동) 1~2층
# 전화번호                    053-522-0666
# Name: 6, dtype: object
# 매장이름                 대구중동점
# 지역                  대구 수성구
# 주소      대구 수성구 중동 322-14 .
# 전화번호          053-767-4326
# Name: 47, dtype: object
# 매장이름                    메가박스프리미엄만경관점
# 지역                             대구 서구
# 주소      대구 중구 국채보상로 547 MMC 만경관 4층 .
# 전화번호                   070-7717-2192
# Name: 103, dtype: object
# 매장이름                      대구봉무공원점
# 지역                          대구 동구
# 주소      대구광역시 동구 단산길 4 (봉무동) 1~2층
# 전화번호                 053-984-3001
# Name: 183, dtype: object
# 매장이름                              대구수성네거리점
# 지역                                  대구 수성구
# 주소      대구광역시 수성구 들안로 326 1,2층 수성동3가 254-2
# 전화번호                          053-743-8700
# ...

# %%
3*False
# Out:
# 0

# %%
import pandas as pd
from tabulate import tabulate

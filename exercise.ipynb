# %%
class Counter:
    def __init__(self):
        self.count=0

    def increment(self):
        self.count+=1

# %%
a=Counter()
a.count
# Out:
# 0

# %%
inventory_dict={'coffee':100,'cream':100,'sugar':100,'water':500,'cup':5,'change':0}
print(inventory_dict.items())
# Out:
# dict_items([('coffee', 100), ('cream', 100), ('sugar', 100), ('water', 500), ('cup', 5), ('change', 0)])

# %%
inventory_dict['coffee']
# Out:
# 100

# %%
nn=[[1,2,3,4],[2,3]]

# %%
len(nn[1])
# Out:
# 2

# %%
import pandas as pd

# %%
aa=pd.DataFrame({'a':[1,2,3,4],'b':[5,7,8,9]})
aa
# Out:
#    a  b
# 0  1  5
# 1  2  7
# 2  3  8
# 3  4  9

# %%
for i in aa:
    print(i)
# Out:
# a
# b

# %%
a=[1,2,3,4,5]
b=[1,2]

# %%
for i in b:
    a.remove(i)

# %%
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 1, 2]

# %%
a.remove(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a.remove(1,2)
#
# TypeError: list.remove() takes exactly one argument (2 given)

# %%
a=list()

# %%
a is None
# Out:
# False

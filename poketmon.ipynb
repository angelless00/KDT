# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_sti(have):
    bad=have/total
    if np.random.rand()<bad:
        have=have
    else:
        have=have+1
    return have

# %%
num=[]
for _ in range(500):
    have=1
    total=20
    n=0
    while have<total:
        n=n+1
        have=get_sti(have)
    num.append(n)
    

print(num)
plt.hist(num)
plt.show()
# Out:
# [59, 109, 61, 63, 30, 74, 82, 41, 79, 90, 29, 52, 44, 80, 112, 88, 52, 36, 59, 45, 76, 54, 70, 44, 62, 39, 148, 72, 63, 112, 78, 58, 64, 44, 112, 91, 74, 109, 92, 85, 62, 108, 79, 101, 67, 34, 47, 45, 39, 72, 46, 118, 59, 88, 43, 79, 77, 35, 65, 51, 103, 66, 41, 113, 66, 69, 74, 93, 69, 56, 63, 56, 28, 65, 51, 63, 70, 70, 47, 71, 53, 62, 72, 45, 58, 57, 57, 54, 92, 45, 60, 36, 51, 41, 34, 86, 122, 33, 87, 42, 45, 75, 44, 69, 109, 34, 53, 59, 86, 41, 105, 34, 150, 92, 77, 61, 52, 126, 45, 47, 48, 68, 96, 93, 83, 104, 67, 100, 45, 72, 42, 110, 60, 69, 65, 71, 66, 52, 125, 69, 103, 51, 108, 57, 68, 42, 57, 41, 56, 90, 38, 58, 66, 77, 66, 70, 39, 67, 68, 114, 56, 58, 74, 53, 46, 75, 89, 62, 60, 43, 61, 89, 40, 79, 50, 50, 109, 48, 66, 87, 90, 102, 83, 49, 69, 82, 60, 47, 65, 60, 53, 53, 57, 66, 64, 42, 51, 81, 77, 64, 71, 57, 55, 108, 99, 63, 59, 116, 137, 65, 91, 50, 48, 56, 157, 78, 83, 78, 34, 47, 44, 43, 40, 126, 43, 126, 97, 97, 66, 59, 116, 71, 65, 69, 111, 75, 64, 69, 54, 94, 51, 
# ...

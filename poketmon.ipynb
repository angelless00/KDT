# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_sti(have):
    bad=have/total
    if np.random.rand()<bad:
        have=have
    else:
        have=have+1
    return have

# %%
num=[]
for _ in range(500):
    have=1
    total=150
    n=0
    while have<total:
        n=n+1
        have=get_sti(have)
    num.append(n)
    

print(num)
plt.hist(num)
plt.show()
# Out:
# [712, 705, 821, 599, 945, 860, 723, 1116, 962, 1021, 783, 1002, 662, 658, 489, 1165, 886, 1235, 991, 1329, 1116, 658, 822, 787, 971, 871, 1007, 752, 866, 1188, 1004, 1341, 923, 668, 573, 744, 709, 767, 650, 747, 756, 665, 698, 1218, 971, 1052, 1206, 665, 857, 778, 1745, 660, 687, 1000, 619, 1403, 698, 1014, 858, 823, 735, 1689, 765, 779, 883, 857, 952, 968, 1216, 725, 1174, 907, 570, 870, 671, 896, 1329, 681, 634, 660, 1266, 899, 712, 599, 810, 858, 1079, 819, 711, 706, 888, 809, 739, 785, 1615, 921, 796, 714, 786, 598, 1091, 825, 1110, 565, 675, 803, 780, 686, 920, 780, 749, 730, 788, 830, 660, 974, 748, 640, 1199, 802, 1047, 961, 884, 887, 637, 755, 949, 851, 905, 1022, 798, 1002, 609, 947, 656, 792, 1110, 585, 776, 704, 930, 869, 525, 1295, 1016, 612, 957, 676, 1131, 694, 914, 765, 696, 888, 1033, 740, 921, 1133, 884, 766, 793, 818, 743, 815, 1031, 778, 708, 924, 723, 924, 830, 1581, 1145, 667, 703, 901, 1477, 794, 883, 684, 739, 1003, 1166, 690, 914, 842, 867, 747, 1344, 1095, 73
# ...

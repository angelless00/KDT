# %% [markdown]
# ### DNN 기반 이진분류 모델 구현 및 학습 모니터링과 저장 <hr>
# - 데이터셋 : iris.csv
# - 피쳐/속성 : 4개 Sepal_Length, Sepan_Width, Petal_ Length, Peatal_Width
# - 타겟/라벨 : 1개 Setosa와 나머지
# - 학습방벙 : 지도학습 > 분류 > 이진 분류
# - 알고리즘 : 인공신경망 (ANN) -> MLP(Multi Layer Percetron),  심층신경망(DNN)(은닉층 多)
# - 프레임워크 : Pytorch
# ---

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비  <hr>

# %%
# 모듈로딩
# Model 관련
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset,DataLoader
import torch.optim as optim
from torchmetrics.classification import  F1Score, BinaryF1Score, BinaryConfusionMatrix
from torchinfo import summary

# - Data관련
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from sklearn.model_selection import train_test_split

# %%
# 활용 패키지 버전 체크 - 사용자 정의 함수로 구현할것!
print(f'Pytorch v.{torch.__version__}')
print(f'Pandas v.{pd.__version__}')
# Out:
# Pytorch v.2.4.1
# Pandas v.2.0.3

# %%
## 데이터로딩
DATA_FILE='../../MachineLearning/data/iris.csv'

## CSV >> DataFrame
irisDF=pd.read_csv(DATA_FILE)

## 확인
irisDF.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
### 타겟 변경 => 정수화, 클래스3개 =>2개
irisDF['variety'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
irisDF['variety']=(irisDF['variety']=='Setosa')
irisDF.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0           5.1          3.5           1.4          0.2     True
# 1           4.9          3.0           1.4          0.2     True
# 2           4.7          3.2           1.3          0.2     True
# 3           4.6          3.1           1.5          0.2     True
# 4           5.0          3.6           1.4          0.2     True

# %%
irisDF['variety']=irisDF['variety'].astype('int')
irisDF['variety'].unique()
# Out:
# array([1, 0])

# %%
# 타겟 정수화
labels=dict(zip(irisDF['variety'].unique().tolist(),range(3)))
print(f'labels=> {labels}')
# 라벨인코딩<<
# Out:
# labels=> {1: 0, 0: 1}

# %% [markdown]
# [2] 모델 클래스 설계 및 정의 <hr>
# - 클래스목적 : iris 데이터를 학습 및 추론 목적
# - 클래스이름 : IrisBCFModel
# - 부모클래스 : nn.Module
# - 매개변수 : 층별 입출력 갯수 고정하므로 필요 없음
# - 속성/필드 : featruesDF, targetDF, n_rows, n_features
# - 기능/역할 <필수 >
#     -  __ init __() : 모델 구조 설정
#     - forward() : 순방향 학습 <- 오버라이딩(overriding)
# - 클래스구조
#     - 입력층 : 입력 4개 / 출력 10개 (퍼셉트론/뉴런 10개 존재)
#     - 은닉층 : 입력 10개 / 출력 5개 (퍼셉트론/뉴런 30개 존재)
#     - 출력층 : 입력 5개 / 출력 1개 (2진분류)
# - 손실함수/ 활성화함수
#     - 클래스형태 => nn. 아래
#         - ex) nn.ReLu << __init__() 에 사용
#     - 함수 형태 => torch.nn.functional 아래
#         - ex) F.relu << def forward() 에 사용

# %%
class IrisBCFModel(nn.Module):

    # 모델 구조 구성 및 인스턴스 생성 메서드
    def __init__(self):
        super().__init__()

        self.in_layer=nn.Linear(4,10)
        self.hd_layer=nn.Linear(10,5)
        self.out_layer=nn.Linear(5,1)

    # 순방향 학습 진행 메서드
    def forward(self,x):
        # - 입력층
        y=self.in_layer(x)        # f1_1w1_1+f1_2w1_2+f1_3w1_3+b << 이런식 10개
        y=F.relu(y)

        # - 은닉층 : 10개의 숫자값 (>=0)
        y=self.hd_layer(y)        # f2_1w2_1+f2_2w2_2+....f2_10w2_10 +b << 이런식 5개
        y=F.relu(y)

        # - 출력층 : 5개의 숫자값 (>=0) - 이진분류
        return F.sigmoid(self.out_layer(y))         # f3_1w3_1+.....f3_30w3_30+b << 1 개

# %%
### [테스트] 모델 인스턴스 생성
model=IrisBCFModel()

print(model)
# Out:
# IrisBCFModel(
#   (in_layer): Linear(in_features=4, out_features=10, bias=True)
#   (hd_layer): Linear(in_features=10, out_features=5, bias=True)
#   (out_layer): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
### [테스트] 모델 확인
summary(model,input_size=(17,4))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# IrisBCFModel                             [17, 1]                   --
# ├─Linear: 1-1                            [17, 10]                  50
# ├─Linear: 1-2                            [17, 5]                   55
# ├─Linear: 1-3                            [17, 1]                   6
# ==========================================================================================
# Total params: 111
# Trainable params: 111
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================

# %% [markdown]
# [3] 데이터셋 클래스 설계 및 정의 <hr>
# - 데이터셋 : iris.csv
# - 피쳐개수 : 4개
# - 타겟개수 : 1개
# - 클래스이름 : IrisDataset
# - 부모클래스 : utils.data.Dataset
# - 속성필드 : featureDF, targetDF, n_rows, n_features
# - 필수메서드
#     - __ init __(self) : 데이터셋 저장 및 전처리, 개발자가 필요한 속성 설정
#     - __ len __(self) : 데이터의 개수 반환
#     - __ getitem __(self,index) : 특정 인덱스의 피쳐와 타겟 반환

# %%
class IrisDataset(Dataset):

    def __init__(self,featureDF,targetDF):
        self.featureDF=featureDF
        self.targetDF=targetDF
        self.n_rows=featureDF.shape[0]      # 필수아님
        self.n_features=featureDF.shape[1]  # 필수아님


    def __len__(self):
        return self.n_rows
        
    def __getitem__(self, index):
        # 텐서화
        featureTS=torch.FloatTensor(self.featureDF.iloc[index].values)
        targetTS=torch.FloatTensor(self.targetDF.iloc[index].values)
        
        # 피쳐와 타겟 반환
        return featureTS, targetTS

# %%
## [테스트] 데이터셋 인스턴스 생성

featureDF=irisDF[irisDF.columns[:4]]        # 2D (150,3)
targetDF=irisDF[irisDF.columns[[4]]]        # 2D (150,1)

# - 커스템데이터셋 인스턴스 생성
irisDS=IrisDataset(featureDF,targetDF)

# 데이터 로드 인스턴스 생성
irisDL=DataLoader(irisDS)
for feature,target in irisDL:
    print(feature,target)
    break
# Out:
# tensor([[5.1000, 3.5000, 1.4000, 0.2000]]) tensor([[1.]])

# %% [markdown]
# [4] 학습 준비
# - 학습횟수 : EPOCH <- 처음부터 끝까지 공부하는 횟수
# - 배치크기 : BATCH_SIZE <- 한번에 학습할 데이터셋 양
# - 위치지정 : DEVICE <- 텐서 저장 및 실행 위치 (GPU/CPU)
# - 학습률(LR, learning Rate) : 가중치와 절편 업데이트 시 경사하강법으로 업데이트 간격 설정 0.001~0.1

# %%
### 학습 진행 관련 설정 값 
EPOCH = 100
BATCH_SIZE= 10
DEVICE ='cuda' if torch.cuda.is_available() else 'cpu'
LR=0.001

# %% [markdown]
# - 인스턴스/객체 : 모델, 데이터셋, 최적화, 손실함수 (, 성능지표)

# %%
# 모델 인스턴스
model= IrisBCFModel()

# 데이터셋 인스턴스
# # 학습,검증,테스트 데이터 분리
X_train, X_test, y_train, y_test=train_test_split(featureDF,targetDF,random_state=1,stratify=targetDF)
X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,random_state=1,stratify=y_train)
print(f' X_train : {X_train.shape}, X_val : {X_val.shape} , X_test : {X_test.shape}')
print(f' y_train : {y_train.shape}, y_val : {y_val.shape} , y_test : {y_test.shape}')
print(f'{y_train.value_counts()} {y_test.value_counts()} {y_val.value_counts()}')
print(f'{y_train.value_counts()/y_train.shape[0]} {y_test.value_counts()/y_test.shape[0]} {y_val.value_counts()/y_val.shape[0]}')

trainDS=IrisDataset(X_train,y_train)
valDS=IrisDataset(X_val,y_val)
testDS=IrisDataset(X_test,y_test)

# 데이터로더 인스턴스
trainDL=DataLoader(trainDS,batch_size=BATCH_SIZE)
# Out:
#  X_train : (84, 4), X_val : (28, 4) , X_test : (38, 4)
#  y_train : (84, 1), y_val : (28, 1) , y_test : (38, 1)
# variety
# 0          56
# 1          28
# Name: count, dtype: int64 variety
# 0          25
# 1          13
# Name: count, dtype: int64 variety
# 0          19
# 1           9
# Name: count, dtype: int64
# variety
# 0          0.666667
# 1          0.333333
# Name: count, dtype: float64 variety
# 0          0.657895
# 1          0.342105
# Name: count, dtype: float64 variety
# 0          0.678571
# 1          0.321429
# Name: count, dtype: float64

# %% [markdown]
# - 최적화 , 손실함수 인스턴스 생성

# %%
# 최적화 인스턴스 => W,b 텐서 즉, model.parameters() 전달
optimizer=optim.Adam(model.parameters(),lr=LR)

# 손실함수 인스턴스 => 분류 => 이진분류 BinaryCrossEntropyLoss => BCELoss
#                            예측값은 확률값으로 전달 => sigmoid() AF처리후 전달
bceLoss=nn.BCELoss()

# %% [markdown]
# [5] 학습진행

# %%
len(trainDL),trainDL.__len__()
# Out:
# (9, 9)

# %%
## 학습의 효과 확인 손실값과 성능 평가값 저장 필요
LOSS_HISTORY,SCORE_HISTORY=[[],[]],[[],[]]

# 학습 모드로 모델 설정
 
for epoch in range(EPOCH):
    model.train()  ## 학습모드 켜기! 에포크 단위로 학습과 검증 진행시 for문안에서 껐다 켯다 해야함! 

    # 배치 크기 만큼 데이터 로딩해서 학습 진행
    loss_total=0
    score_total=0
    for featureTS,targetTS in trainDL:

        # 학습 진행
        pre_y=model(featureTS)

        # 손실 계산
        loss=bceLoss(pre_y,targetTS)
        loss_total+=loss.item()

        # 성능평가 계산
        score=BinaryF1Score()(pre_y,targetTS)
        score_total+=score.item()

        # 최적화 진행
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    model.eval() # 검증모드 켜기!
    with torch.no_grad():
        # 검증데이터셋
        val_featureTS=torch.FloatTensor(valDS.featureDF.values)
        val_targetTS=torch.FloatTensor(valDS.targetDF.values)

        # 평가
        pre_val = model(val_featureTS)
        #손실
        val_loss=bceLoss(pre_val,val_targetTS)
        # 성능평가
        val_score=BinaryF1Score()(pre_val,val_targetTS)
    
    # 손실값과 성능 평가값 저장
    LOSS_HISTORY[0].append(loss_total/len(trainDL))
    SCORE_HISTORY[0].append(score_total/len(trainDL))

    LOSS_HISTORY[1].append(val_loss)
    SCORE_HISTORY[1].append(val_score)

    print(f'[{epoch}/{EPOCH}]')
    print(f'trainloss={loss_total/len(trainDL)} trainscore={score_total/len(trainDL)}')
    print(f'valloss={val_loss} trainscore={val_score}')
# Out:
# [0/100]
# trainloss=0.7303482890129089 trainscore=0.4984275135729048
# valloss=0.716887891292572 trainscore=0.4864864945411682
# [1/100]
# trainloss=0.6987737947040134 trainscore=0.4984275135729048
# valloss=0.684647262096405 trainscore=0.4864864945411682
# [2/100]
# trainloss=0.6705595254898071 trainscore=0.5132423275046878
# valloss=0.6547378301620483 trainscore=0.529411792755127
# [3/100]
# trainloss=0.6437204943762885 trainscore=0.6568542702330483
# valloss=0.6265102624893188 trainscore=0.8181818127632141
# [4/100]
# trainloss=0.6179939111073812 trainscore=0.8216931256983016
# valloss=0.5993121266365051 trainscore=0.9473684430122375
# [5/100]
# trainloss=0.5928848650720384 trainscore=0.9841269850730896
# valloss=0.5730932354927063 trainscore=1.0
# [6/100]
# trainloss=0.569743812084198 trainscore=1.0
# valloss=0.550399124622345 trainscore=1.0
# [7/100]
# trainloss=0.5494009322590299 trainscore=1.0
# valloss=0.5295576453208923 trainscore=1.0
# [8/100]
# trainloss=0.5303644471698337 trainscore=1.0
# valloss=0.509865939617157 trainscore=1.0
# [9/100]
# trainloss=0.5121366083621979 trainscore=1.0
# valloss=0.48919013142585754 trainscore=1.0
# [10/100]
# trainloss=0.49248472849527997 trainscore=1.0
# valloss=0.46735861897468567 trainscore=1.0
# [11/100]
# trainloss=0.47181908620728386 trainscore=1.0
# valloss=0.44484689831733704 trainscore=1.0
# [12/100]
# trainloss=0.45047353704770404 trainscore=1.0
# valloss=0.42192313075065613 trainscore=1.0
# [13/100]
# trainloss=0.42867659197913277 trainscore=1.0
# valloss=0.3988245129585266 trainscore=1.0
# [14/100]
# trainloss=0.4066898756557041 trainscore=1.0
# valloss=0.375792920589447 trainscore=1.0
# [15/100]
# trainloss=0.3847644130388896 trainscore=1.0
# valloss=0.3531896471977234 trainscore=1.0
# [16/100]
# trainloss=0.3632305893633101 trainscore=1.0
# valloss=0.3311610519886017 trainscore=1.0
# [17/100]
# trainloss=0.34217865268389386 trainscore=1.0
# valloss=0.30977901816368103 trainscore=1.0
# [18/100]
# trainloss=0.32178619503974915 trainscore=1.0
# valloss=0.28915753960609436 trainscore=1.0
# [19/100]
# trainloss=0.30195027589797974 trainscore=1.0
# valloss=0.2694120705127716 trainscore=1.0
# [20/100]
# trainloss=0.2827634894185596 trainscore=1.0
# valloss=0.25055137276649475 trainscore=1.0
# [21/100]
# trainloss=0.2643011576599545 trainscore=1.0
# valloss=0.23256351053714752 trainscore=1.0
# [22/100]
# trainloss=0.24659146037366655 trainscore=1.0
# valloss=0.21549613773822784 trainscore=1.0
# [23/100]
# trainloss=0.22969394591119555 trainscore=1.0
# valloss=0.1993667036294937 trainscore=1.0
# [24/100]
# trainloss=0.21366662780443826 trainscore=1.0
# valloss=0.1841692179441452 trainscore=1.0
# [25/100]
# trainloss=0.19853701028558943 trainscore=1.0
# valloss=0.16991589963436127 trainscore=1.0
# [26/100]
# trainloss=0.18430760833952162 trainscore=1.0
# valloss=0.15661607682704926 trainscore=1.0
# [27/100]
# trainloss=0.17097761895921496 trainscore=1.0
# valloss=0.1442680060863495 trainscore=1.0
# [28/100]
# trainloss=0.15850524604320526 trainscore=1.0
# valloss=0.13285847008228302 trainscore=1.0
# [29/100]
# trainloss=0.14685905393626955 trainscore=1.0
# valloss=0.12220096588134766 trainscore=1.0
# [30/100]
# trainloss=0.13569949981239107 trainscore=1.0
# valloss=0.11185257136821747 trainscore=1.0
# [31/100]
# trainloss=0.12452853967746098 trainscore=1.0
# valloss=0.10148002952337265 trainscore=1.0
# [32/100]
# trainloss=0.11324630512131585 trainscore=1.0
# valloss=0.09132909774780273 trainscore=1.0
# [33/100]
# trainloss=0.10253127995464537 trainscore=1.0
# valloss=0.08227253705263138 trainscore=1.0
# [34/100]
# trainloss=0.09356807255082661 trainscore=1.0
# valloss=0.07441965490579605 trainscore=1.0
# [35/100]
# trainloss=0.08544068452384737 trainscore=1.0
# valloss=0.06736334413290024 trainscore=1.0
# [36/100]
# trainloss=0.07803402220209439 trainscore=1.0
# valloss=0.06115156412124634 trainscore=1.0
# [37/100]
# trainloss=0.07140934550099903 trainscore=1.0
# valloss=0.05568688362836838 trainscore=1.0
# [38/100]
# trainloss=0.06550597440865305 trainscore=1.0
# valloss=0.050831057131290436 trainscore=1.0
# [39/100]
# trainloss=0.060233144296540156 trainscore=1.0
# valloss=0.046520836651325226 trainscore=1.0
# [40/100]
# trainloss=0.05552671725551287 trainscore=1.0
# valloss=0.04268157109618187 trainscore=1.0
# [41/100]
# trainloss=0.0512998609079255 trainscore=1.0
# valloss=0.03925738111138344 trainscore=1.0
# [42/100]
# trainloss=0.04748926932613055 trainscore=1.0
# valloss=0.03619295358657837 trainscore=1.0
# [43/100]
# trainloss=0.044051168486475945 trainscore=1.0
# valloss=0.03344332054257393 trainscore=1.0
# [44/100]
# trainloss=0.04095276010533174 trainscore=1.0
# valloss=0.0309803057461977 trainscore=1.0
# [45/100]
# trainloss=0.03815237763855192 trainscore=1.0
# valloss=0.028759775683283806 trainscore=1.0
# [46/100]
# trainloss=0.03561972495582369 trainscore=1.0
# valloss=0.026758398860692978 trainscore=1.0
# [47/100]
# trainloss=0.033325080656343035 trainscore=1.0
# valloss=0.024952951818704605 trainscore=1.0
# [48/100]
# trainloss=0.031236720581849415 trainscore=1.0
# valloss=0.023315226659178734 trainscore=1.0
# [49/100]
# trainloss=0.02933013728923268 trainscore=1.0
# valloss=0.02183004654943943 trainscore=1.0
# [50/100]
# trainloss=0.027582943853404786 trainscore=1.0
# valloss=0.020478466525673866 trainscore=1.0
# [51/100]
# trainloss=0.02598473967777358 trainscore=1.0
# valloss=0.019242268055677414 trainscore=1.0
# [52/100]
# trainloss=0.02451864340239101 trainscore=1.0
# valloss=0.018109766766428947 trainscore=1.0
# [53/100]
# trainloss=0.023171174236469798 trainscore=1.0
# valloss=0.01707073487341404 trainscore=1.0
# [54/100]
# trainloss=0.021926447024775877 trainscore=1.0
# valloss=0.01611379161477089 trainscore=1.0
# [55/100]
# trainloss=0.020779125495917268 trainscore=1.0
# valloss=0.015231861732900143 trainscore=1.0
# [56/100]
# trainloss=0.01971763124068578 trainscore=1.0
# valloss=0.014418169856071472 trainscore=1.0
# [57/100]
# trainloss=0.018734298542969756 trainscore=1.0
# valloss=0.013665886595845222 trainscore=1.0
# [58/100]
# trainloss=0.01782257409973277 trainscore=1.0
# valloss=0.012969417497515678 trainscore=1.0
# [59/100]
# trainloss=0.01697311167501741 trainscore=1.0
# valloss=0.012324364855885506 trainscore=1.0
# [60/100]
# trainloss=0.01618256399201022 trainscore=1.0
# valloss=0.011723996140062809 trainscore=1.0
# [61/100]
# trainloss=0.015448097139596939 trainscore=1.0
# valloss=0.011165897361934185 trainscore=1.0
# [62/100]
# trainloss=0.014761157126890289 trainscore=1.0
# valloss=0.010646008886396885 trainscore=1.0
# [63/100]
# trainloss=0.014117465561462773 trainscore=1.0
# valloss=0.010160361416637897 trainscore=1.0
# [64/100]
# trainloss=0.013513641018006537 trainscore=1.0
# valloss=0.009705536998808384 trainscore=1.0
# [65/100]
# trainloss=0.012948629911988974 trainscore=1.0
# valloss=0.009279354475438595 trainscore=1.0
# [66/100]
# trainloss=0.01242039269871182 trainscore=1.0
# valloss=0.008880039677023888 trainscore=1.0
# [67/100]
# trainloss=0.011924562458362844 trainscore=1.0
# valloss=0.008505473844707012 trainscore=1.0
# [68/100]
# trainloss=0.011457728325492807 trainscore=1.0
# valloss=0.008153640665113926 trainscore=1.0
# [69/100]
# trainloss=0.011017401599221759 trainscore=1.0
# valloss=0.007822711020708084 trainscore=1.0
# [70/100]
# trainloss=0.010601266390747495 trainscore=1.0
# valloss=0.007510602008551359 trainscore=1.0
# [71/100]
# trainloss=0.010209889409856664 trainscore=1.0
# valloss=0.007216502446681261 trainscore=1.0
# [72/100]
# trainloss=0.009840317639625736 trainscore=1.0
# valloss=0.006939768325537443 trainscore=1.0
# [73/100]
# trainloss=0.009490798589669995 trainscore=1.0
# valloss=0.006678663194179535 trainscore=1.0
# [74/100]
# trainloss=0.009159725521587662 trainscore=1.0
# valloss=0.0064321281388401985 trainscore=1.0
# [75/100]
# trainloss=0.008845561856610907 trainscore=1.0
# valloss=0.006199382711201906 trainscore=1.0
# [76/100]
# trainloss=0.008547049377941422 trainscore=1.0
# valloss=0.005979118403047323 trainscore=1.0
# [77/100]
# trainloss=0.008263135484109322 trainscore=1.0
# valloss=0.005770145915448666 trainscore=1.0
# [78/100]
# trainloss=0.007992908513794342 trainscore=1.0
# valloss=0.005571771413087845 trainscore=1.0
# [79/100]
# trainloss=0.007735520859973298 trainscore=1.0
# valloss=0.005383708048611879 trainscore=1.0
# [80/100]
# trainloss=0.007490196627461248 trainscore=1.0
# valloss=0.005204743705689907 trainscore=1.0
# [81/100]
# trainloss=0.007256311235121555 trainscore=1.0
# valloss=0.005034421570599079 trainscore=1.0
# [82/100]
# trainloss=0.007033123945196469 trainscore=1.0
# valloss=0.004872404970228672 trainscore=1.0
# [83/100]
# trainloss=0.006819969405316644 trainscore=1.0
# valloss=0.004718228243291378 trainscore=1.0
# [84/100]
# trainloss=0.006616271773560179 trainscore=1.0
# valloss=0.004571065306663513 trainscore=1.0
# [85/100]
# trainloss=0.006421214228288995 trainscore=1.0
# valloss=0.004430053755640984 trainscore=1.0
# [86/100]
# trainloss=0.006235036300495267 trainscore=1.0
# valloss=0.004295052494853735 trainscore=1.0
# [87/100]
# trainloss=0.0060570562361843055 trainscore=1.0
# valloss=0.004165953490883112 trainscore=1.0
# [88/100]
# trainloss=0.005886222209988369 trainscore=1.0
# valloss=0.004041883163154125 trainscore=1.0
# [89/100]
# trainloss=0.0057230015388793415 trainscore=1.0
# valloss=0.0039230710826814175 trainscore=1.0
# [90/100]
# trainloss=0.005566803350423773 trainscore=1.0
# valloss=0.003809545189142227 trainscore=1.0
# [91/100]
# trainloss=0.005416996492486861 trainscore=1.0
# valloss=0.0037008393555879593 trainscore=1.0
# [92/100]
# trainloss=0.005273219767130083 trainscore=1.0
# valloss=0.003596717258915305 trainscore=1.0
# [93/100]
# trainloss=0.005134912595773737 trainscore=1.0
# valloss=0.003496853867545724 trainscore=1.0
# [94/100]
# trainloss=0.005002186349075701 trainscore=1.0
# valloss=0.003401194466277957 trainscore=1.0
# [95/100]
# trainloss=0.0048744953237473965 trainscore=1.0
# valloss=0.003309239400550723 trainscore=1.0
# [96/100]
# trainloss=0.004751712213166886 trainscore=1.0
# valloss=0.0032208035700023174 trainscore=1.0
# [97/100]
# trainloss=0.004633579299681717 trainscore=1.0
# valloss=0.0031357973348349333 trainscore=1.0
# [98/100]
# trainloss=0.004519766558789545 trainscore=1.0
# valloss=0.003054057015106082 trainscore=1.0
# [99/100]
# trainloss=0.0044100959526581895 trainscore=1.0
# valloss=0.002975383074954152 trainscore=1.0

# %% [markdown]
# - 학습결과 체크 => 학습과 검증의 Loss변화, 성능변화

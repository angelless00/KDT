# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
feature=pd.read_csv('feature.csv')
target=pd.read_csv('target.csv')

# %%
feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8328 entries, 0 to 8327
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_retweet_count       8328 non-null   int64
#  1   total_favorite_count      8328 non-null   int64
#  2   total_hashtag_count       8328 non-null   int64
#  3   total_url_count           8328 non-null   int64
#  4   total_mentions_count      8328 non-null   int64
#  5   total_media_count         8328 non-null   int64
#  6   number_of_tweets_scraped  8328 non-null   float64
# dtypes: float64(1), int64(6)
# memory usage: 455.6 KB

# %%
targetSR=target['mbti_personality']

# %%
for row in target.index:
    # ie 구분
    if 'i' in target.loc[row,'mbti_personality']:
        target.loc[row,'ie']='i'
    else: target.loc[row,'ie']='e'

    # ns 구분
    if 'n' in target.loc[row,'mbti_personality']:
        target.loc[row,'ns']='n'
    else: target.loc[row,'ns']='s'

    # ft 구분
    if 'f' in target.loc[row,'mbti_personality']:
        target.loc[row,'ft']='f'
    else: target.loc[row,'ft']='t'

    # jp구분
    if 'j' in target.loc[row,'mbti_personality']:
        target.loc[row,'jp']='j'
    else: target.loc[row,'jp']='p'

# %%
#target.to_csv('target_2.csv',index=False)

# %% [markdown]
# ## 데이터 확인

# %%
target_ie=target['ie']
target_ns=target['ns']
target_ft=target['ft']
target_jp=target['jp']

# %%
j_feature=feature[target_jp=='j']
p_feature=feature[target_jp=='p']
fig,ax=plt.subplots(figsize=(9,6),ncols=3,nrows=2)
for i in range(6):
    ax[i//3,i%3].hist(j_feature[feature.columns[i]],label='j')
    ax[i//3,i%3].hist(-p_feature[feature.columns[i]],label='p')
    ax[i//3,i%3].set(title=feature.columns[i])
plt.tight_layout()
plt.legend()

# %% [markdown]
# ## 데이터셋 분리

# %%
target_jp.replace('j',0,inplace=True)
target_jp.replace('p',1,inplace=True)

# %%
from sklearn.model_selection import train_test_split, cross_validate
# Out:
# c:\Users\KDP-30\anaconda3\envs\TEXT_018_230_38\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
X_train,X_test,y_train,y_test=train_test_split(feature,target_jp,stratify=targetSR,random_state=38)

# %%
y_train.value_counts()
# Out:
# jp
# 0    3331
# 1    2915
# Name: count, dtype: int64

# %% [markdown]
# ## 스케일링

# %% [markdown]
# ## 학습

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(random_state=38)

# %%
model.fit(X_train,y_train)
print(f'train score : {model.score(X_train,y_train)}')
print(f'test score : {model.score(X_test,y_test)}')
# Out:
# train score : 0.999839897534422
# test score : 0.5326609029779059

# %% [markdown]
# ## 튜닝

# %%
from sklearn.model_selection import RandomizedSearchCV

# RandomForestClassfier 하이퍼 파라미터 설정
params={'max_depth':range(5,15),'min_samples_leaf':range(5,25)}

searchCV=RandomizedSearchCV(model,
                            param_distributions=params,
                            verbose=4)

searchCV.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ..max_depth=7, min_samples_leaf=23;, score=0.540 total time=   0.5s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=23;, score=0.556 total time=   0.6s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=23;, score=0.548 total time=   0.7s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=23;, score=0.532 total time=   0.6s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=23;, score=0.559 total time=   0.6s
# [CV 1/5] END .max_depth=14, min_samples_leaf=17;, score=0.546 total time=   0.9s
# [CV 2/5] END .max_depth=14, min_samples_leaf=17;, score=0.546 total time=   1.0s
# [CV 3/5] END .max_depth=14, min_samples_leaf=17;, score=0.548 total time=   0.9s
# [CV 4/5] END .max_depth=14, min_samples_leaf=17;, score=0.528 total time=   0.8s
# [CV 5/5] END .max_depth=14, min_samples_leaf=17;, score=0.551 total time=   0.8s
# [CV 1/5] END .max_depth=10, min_samples_leaf=17;, score=0.542 total time=   0.7s
# [CV 2/5] END .max_depth=10, min_samples_leaf=17;, score=0.555 total time=   0.8s
# [CV 3/5] END .max_depth=10, min_samples_leaf=17;, score=0.548 total time=   0.7s
# [CV 4/5] END .max_depth=10, min_samples_leaf=17;, score=0.528 total time=   0.7s
# [CV 5/5] END .max_depth=10, min_samples_leaf=17;, score=0.542 total time=   0.7s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=11;, score=0.549 total time=   0.6s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=11;, score=0.557 total time=   0.6s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=11;, score=0.544 total time=   0.6s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=11;, score=0.530 total time=   0.7s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=11;, score=0.546 total time=   0.7s
# [CV 1/5] END .max_depth=13, min_samples_leaf=21;, score=0.552 total time=   0.9s
# [CV 2/5] END .max_depth=13, min_samples_leaf=21;, score=0.547 total time=   0.9s
# [CV 3/5] END .max_depth=13, min_samples_leaf=21;, score=0.551 total time=   0.9s
# [CV 4/5] END .max_depth=13, min_samples_leaf=21;, score=0.532 total time=   0.9s
# [CV 5/5] END .max_depth=13, min_samples_leaf=21;, score=0.554 total time=   0.9s
# [CV 1/5] END ..max_depth=12, min_samples_leaf=7;, score=0.538 total time=   1.0s
# [CV 2/5] END ..max_depth=12, min_samples_leaf=7;, score=0.556 total time=   1.1s
# [CV 3/5] END ..max_depth=12, min_samples_leaf=7;, score=0.556 total time=   1.1s
# [CV 4/5] END ..max_depth=12, min_samples_leaf=7;, score=0.525 total time=   1.0s
# [CV 5/5] END ..max_depth=12, min_samples_leaf=7;, score=0.537 total time=   1.2s
# [CV 1/5] END ..max_depth=8, min_samples_leaf=15;, score=0.531 total time=   1.0s
# [CV 2/5] END ..max_depth=8, min_samples_leaf=15;, score=0.561 total time=   0.9s
# [CV 3/5] END ..max_depth=8, min_samples_leaf=15;, score=0.539 total time=   0.9s
# [CV 4/5] END ..max_depth=8, min_samples_leaf=15;, score=0.520 total time=   1.0s
# [CV 5/5] END ..max_depth=8, min_samples_leaf=15;, score=0.546 total time=   0.8s
# [CV 1/5] END ..max_depth=13, min_samples_leaf=8;, score=0.542 total time=   1.1s
# [CV 2/5] END ..max_depth=13, min_samples_leaf=8;, score=0.559 total time=   1.1s
# [CV 3/5] END ..max_depth=13, min_samples_leaf=8;, score=0.542 total time=   1.0s
# [CV 4/5] END ..max_depth=13, min_samples_leaf=8;, score=0.528 total time=   1.0s
# [CV 5/5] END ..max_depth=13, min_samples_leaf=8;, score=0.540 total time=   1.0s
# [CV 1/5] END ..max_depth=5, min_samples_leaf=13;, score=0.540 total time=   0.4s
# [CV 2/5] END ..max_depth=5, min_samples_leaf=13;, score=0.555 total time=   0.5s
# [CV 3/5] END ..max_depth=5, min_samples_leaf=13;, score=0.552 total time=   0.5s
# [CV 4/5] END ..max_depth=5, min_samples_leaf=13;, score=0.529 total time=   0.4s
# [CV 5/5] END ..max_depth=5, min_samples_leaf=13;, score=0.555 total time=   0.5s
# [CV 1/5] END ..max_depth=5, min_samples_leaf=14;, score=0.546 total time=   0.4s
# [CV 2/5] END ..max_depth=5, min_samples_leaf=14;, score=0.562 total time=   0.5s
# [CV 3/5] END ..max_depth=5, min_samples_leaf=14;, score=0.549 total time=   0.5s
# [CV 4/5] END ..max_depth=5, min_samples_leaf=14;, score=0.531 total time=   0.5s
# [CV 5/5] END ..max_depth=5, min_samples_leaf=14;, score=0.554 total time=   0.4s
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=38),
#                    param_distributions={'max_depth': range(5, 15),
#                                         'min_samples_leaf': range(5, 25)},
#                    verbose=4)

# %%
print(f'max depth {searchCV.best_estimator_.max_depth}')
print(f'min_samples_leaf {searchCV.best_estimator_.min_samples_leaf}')
# Out:
# max depth 5
# min_samples_leaf 14

# %%
searchCV.best_estimator_.score(X_train,y_train)
# Out:
# 0.5975024015369836

# %%
searchCV.best_estimator_.score(X_test,y_test)
# Out:
# 0.5686839577329491

# %% [markdown]
# ## 성능지표

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix

pred=searchCV.best_estimator_.predict(X_test)
print(f'정확도 { accuracy_score(y_test,pred)} 정밀도 {precision_score(y_test,pred)} 재현율 {recall_score(y_test,pred)}')
# Out:
# 정확도 0.5686839577329491 정밀도 0.5708812260536399 재현율 0.3065843621399177

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[886 224]
#  [674 298]]

# %%
from sklearn.metrics import roc_curve
pred_proba=searchCV.best_estimator_.predict_proba(X_test)[:,1]

fprs,tprs,thresholds=roc_curve(y_test,pred_proba)
plt.plot(fprs,tprs,label='ROC')
plt.plot([0,1],[0,1],'k-')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()

# %%
searchCV.best_estimator_.feature_importances_
# Out:
# array([0.13140547, 0.15261906, 0.16402783, 0.20434427, 0.130695  ,
#        0.10696615, 0.1099422 ])

# %%
import os
import torch
num='jp'
model=searchCV.best_estimator_
# 모델 폴더가 없다면 생성
if not os.path.exists('model/'):
    os.mkdir('model/')


torch.save(model,f'model/best_model_{num}.pth')
